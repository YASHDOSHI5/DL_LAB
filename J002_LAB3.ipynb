# %%
#Importing Libraries
 
from __future__ import print_function
import numpy as np
from keras.utils.np_utils import to_categorical
from keras import models
from keras.layers import Dense, Dropout
from keras.models import Sequential
from keras.layers import Activation, Flatten, Conv2D,MaxPooling2D
from keras.utils.vis_utils import model_to_dot
from IPython.display import SVG
from keras.preprocessing.image import ImageDataGenerator
from keras import layers

import keras
from keras.datasets import cifar10
from keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
# Setting the Random Seed
random.seed(10)

# %%
from keras.datasets import cifar10
#import dataset
(X_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
#Input image dimensions
img_rows, img_cols = 32, 32
num_classes = 2
#The data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# EXTRACTING CATS(LABEL=3) and DOGS(LABEL=5) IMAGES
train_picks = np.ravel(np.logical_or(y_train==3,y_train==5))  
test_picks = np.ravel(np.logical_or(y_test==3,y_test==5))
y_train = np.array(y_train[train_picks]==5,dtype=int)
y_test = np.array(y_test[test_picks]==5,dtype=int)
x_train = x_train[train_picks]
x_test = x_test[test_picks]

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 3, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 3, img_rows, img_cols)
    input_shape = (3, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 3)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 3)
    input_shape = (img_rows, img_cols, 3)
    
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')


#Convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(np.ravel(y_train), num_classes)
y_test = keras.utils.to_categorical(np.ravel(y_test), num_classes)

#Look at the first 9 images from the dataset
images = range(0,9)
for i in images:
    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    
#Show the plot
plt.show()
# Out:
# x_train shape: (10000, 32, 32, 3)
# 10000 train samples
# 2000 test samples

# %%
X_train = np.concatenate((X_train,x_test))
Y_train = np.concatenate((y_train, y_test))

# %%
#Image of Cat
plt.imshow(x_train[6000], cmap=plt.get_cmap('gray'))
plt.show()

# %%
 # DEV AND TEST SET
from bs4 import BeautifulSoup
import numpy as np
import requests
import cv2
import PIL.Image
import urllib

ie_page = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n02123045")# Cats synset
print(ie_page.content)
ie_soup = BeautifulSoup(ie_page.content, 'html.parser')#puts the content of the website into the soup variable, each url on a different line
ae_page = requests.get("http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n02084071")# Dogs synset
print(ae_page.content)
ae_soup = BeautifulSoup(ae_page.content, 'html.parser')#puts the content of the website into the soup variable, each url on a different line

ie_str_soup=str(ie_soup)#convert soup to string so it can be split
type(ie_str_soup)
ie_split_urls=ie_str_soup.split('\r\n')#split so each url is a different position on a list
print(len(ie_split_urls))#print the length of the list so you know how many urls you have

ae_str_soup=str(ae_soup)#convert soup to string so it can be split
type(ae_str_soup)
ae_split_urls=ae_str_soup.split('\r\n')#split so each url is a different position on a list
print(len(ae_split_urls))  #print the length of the list so you know how many urls you have
# Out:
# b"http://farm1.static.flickr.com/55/181882736_0b23280b07.jpg\r\nhttp://static.flickr.com/150/361597623_caf7b9c171.jpg\r\nhttp://farm1.static.flickr.com/85/234264322_994b793b69.jpg\r\nhttp://z.about.com/d/cats/1/7/4/0/1/kolohe640x480.jpg\r\nhttp://farm1.static.flickr.com/36/78927720_f45b3c9f6c.jpg\r\nhttp://farm1.static.flickr.com/200/460416306_4294799bf9.jpg\r\nhttp://www.shimmerclaw-cats.co.uk/images/Megabytefr.eSized.jpg\r\nhttp://farm1.static.flickr.com/241/517131023_f3511abd83.jpg\r\nhttp://farm3.static.flickr.com/2231/2234644411_d61dd2c059.jpg\r\nhttp://farm3.static.flickr.com/2224/2185697258_de6724cb56.jpg\r\nhttp://farm1.static.flickr.com/93/271991917_189e8e1c2e.jpg\r\nhttp://farm1.static.flickr.com/21/28185123_bae9bb6590.jpg\r\nhttp://farm3.static.flickr.com/2258/1702122823_056cfb8922.jpg\r\nhttp://farm1.static.flickr.com/70/153100540_c8b80e86f0.jpg\r\nhttp://farm1.static.flickr.com/62/164351244_5c26d331a0.jpg\r\nhttp://farm1.static.flickr.com/224/460434317_814a1b86cb.jpg\r\nhttp://www.catmine.com/figure/01360.jpg\r\nhttp://farm1.static.flickr.com/215/468377924_661df4efd0.jpg\r\nhttp://farm3.static.flickr.com/2278/1923574564_f8dfcef47a.jpg\r\nhttp://farm3.static.flickr.com/2403/1975890847_338bbdcdbb.jpg\r\nhttp://farm1.static.flickr.com/197/490668934_5c47cd860f.jpg\r\nhttp://farm1.static.flickr.com/137/379290139_1a9d3b2c43.jpg\r\nhttp://farm3.static.flickr.com/2149/1953571632_bcef5889ff.jpg\r\nhttp://www.catchat.org/pickford_pix/pickford_waggler.jpg\r\nhttp://farm1.static.flickr.com/46/135314658_f4d2938965.jpg\r\nhttp://farm1.static.flickr.com/6/7799975_f70f6e22bd.jpg\r\nhttp://farm1.static.flickr.com/95/237917954_e5ff2c2a0a.jpg\r\nhttp://static.flickr.com/32/51879196_5a4404873a.jpg\r\nhttp://static.flickr.com/11/14481781_5124d6d3ae.jpg\r\nhttp://farm2.static.flickr.com/1189/1373922446_f6a0dd57ca.jpg\r\nhttp://farm2.static.flickr.com/1062/1075793864_78aee87c9f.jpg\r\nhttp://farm1.static.flickr.com/80/269925534_1124ebd6ce.jpg\r\nhttp://www.friendsfurlifetn.org/adoptedcats/images/Amber2.jpg\r\nhttp://farm1.static.flickr.com/56/140592855_dab44b710f.jpg\r\nhttp://www.bowberrycats.co.uk/images/playing_kitten.jpg\r\nhttp://www.grangeville.us/idahocounty/police/animalcontrol/blkbrncat.JPG\r\nhttp://farm1.static.flickr.com/100/297359990_abf2ead895.jpg\r\nhttp://farm1.static.flickr.com/121/289162768_65f5aacf32.jpg\r\nhttp://farm1.static.flickr.com/90/362747195_c233109f56.jpg\r\nhttp://farm2.static.flickr.com/1197/1057594487_3142826ae7.jpg\r\nhttp://static.flickr.com/228/466233541_b6d8db9b68.jpg\r\nhttp://farm1.static.flickr.com/80/276102660_8694b02829.jpg\r\nhttp://www.pusscats.com/Tabby_Cats-Face.jpg\r\nhttp://farm2.static.flickr.com/1196/528701329_410ded6a36.jpg\r\nhttp://farm1.static.flickr.com/156/336645802_721aa6089b.jpg\r\nhttp://www.toygers.org/images/tequilas.jpg\r\nhttp://farm1.static.flickr.com/238/516234127_12b5af6396.jpg\r\nhttp://farm1.static.flickr.com/18/23841708_69d66bb40a.jpg\r\nhttp://farm2.static.flickr.com/1356/1470331343_af76742e6f.jpg\r\nhttp://farm1.static.flickr.com/180/424751209_d7b0b2de2c.jpg\r\nhttp://farm2.static.flickr.com/1374/856429322_a499f62e1c.jpg\r\nhttp://farm1.static.flickr.com/23/30913564_72135e70f6.jpg\r\nhttp://farm1.static.flickr.com/211/499092719_332a5ab660.jpg\r\nhttp://www.dpw.wau.nl/genetics/teaching/gen10306/Phenotypes%20of%20cats_files/dd.jpg\r\nhttp://images.mooseyscountrygarden.com/cats-and-dogs/t/climbing-tabby-cat.jpg\r\nhttp://farm2.static.flickr.com/1054/1322605357_38d8d7841c.jpg\r\nhttp://farm2.static.flickr.com/1261/1413379559_412a540d29.jpg\r\nhttp://www.oldspringfarm.com/bengalcatimages/02%20Brown%20Spotted%20Tabby%20%20BANX%203.jpg\r\nhttp://farm1.static.flickr.com/122/304961441_e2f09ab556.jpg\r\nhttp://www.artglass-pottery.com/images/cat/ItemCA03841A.jpg\r\nhttp://static.flickr.com/1113/1194296331_263d119a62.jpg\r\nhttp://static.flickr.com/1008/536654114_a1ff85a51a.jpg\r\nhttp://photocache.petfinder.com/fotos/LA132/LA132.4478218-3-x.jpg\r\nhttp://www.biologydaily.com/bi ...
# b"http://farm1.static.flickr.com/164/358144227_01e5544b79.jpg\r\nhttp://www.pantherkut.com/wp-content/uploads/2007/04/2.jpg\r\nhttp://farm3.static.flickr.com/2325/1891011832_cb5d5098c2.jpg\r\nhttp://farm1.static.flickr.com/1/2800688_afe83c164a.jpg\r\nhttp://farm1.static.flickr.com/46/151838410_88d0d8198b.jpg\r\nhttp://www.jameswilsonphotography.com/photogallery/photo3146/Dog.jpg\r\nhttp://farm1.static.flickr.com/147/421773683_7705c66f95.jpg\r\nhttp://farm1.static.flickr.com/48/146403300_0128782865.jpg\r\nhttp://static.flickr.com/5/7220886_ece3a7ecea.jpg\r\nhttp://www.mierdas.es/wp-content/uploads/2006/12/perro-con-dentadura.jpg\r\nhttp://farm2.static.flickr.com/1142/1273843380_424d34d58b.jpg\r\nhttp://farm2.static.flickr.com/1319/917422312_81f0dcce5b.jpg\r\nhttp://www.cosasdeperro.com/wp-content/uploads/2007/10/perro-muerto-exposicion.JPG\r\nhttp://farm1.static.flickr.com/173/406696834_c1e6e29d20.jpg\r\nhttp://farm3.static.flickr.com/2333/2213230621_78dc61e057.jpg\r\nhttp://farm1.static.flickr.com/161/428759207_1b59d0721f.jpg\r\nhttp://farm1.static.flickr.com/107/314290999_efe6f29aa8.jpg\r\nhttp://www.painetworks.com/photos/ii/ii2115.JPG\r\nhttp://static.flickr.com/77/210907433_ce1858c239.jpg\r\nhttp://farm1.static.flickr.com/166/337123823_c7a59a44e9.jpg\r\nhttp://farm1.static.flickr.com/44/142236307_9a364b60b4.jpg\r\nhttp://farm2.static.flickr.com/1339/690883918_0a2ebf2d4a.jpg\r\nhttp://farm1.static.flickr.com/222/512777356_cc623da075.jpg\r\nhttp://farm1.static.flickr.com/189/479504006_e89ab29c9b.jpg\r\nhttp://static.flickr.com/27/65922179_fe6774cccf.jpg\r\nhttp://static.flickr.com/1297/887932010_2b24d8be1d.jpg\r\nhttp://www.petcataract.com/acatalog/pc_dog.jpg\r\nhttp://farm2.static.flickr.com/1012/1356436810_e58eefa640.jpg\r\nhttp://farm3.static.flickr.com/2396/1619436512_37e37aa761.jpg\r\nhttp://lh3.google.com/_NiF18VJ3tZg/RuwfOQjCm9I/AAAAAAAACsg/FIk985EuRYc/s800/FBV062.JPG\r\nhttp://staytondailyphoto.com/photos/sniffles_dog.jpg\r\nhttp://farm1.static.flickr.com/56/143630121_584a901cb5.jpg\r\nhttp://www.tallerdog.com/images/croppeddpa.jpg\r\nhttp://farm1.static.flickr.com/187/441699610_6f574d3d09.jpg\r\nhttp://farm1.static.flickr.com/202/470186220_7595143e12.jpg\r\nhttp://farm1.static.flickr.com/46/217872100_b5709357f7.jpg\r\nhttp://farm3.static.flickr.com/2065/2021522094_e3998b18e0.jpg\r\nhttp://img396.imageshack.us/img396/3181/perro0052kn.jpg\r\nhttp://static.flickr.com/227/513779728_e5f268ef52.jpg\r\nhttp://farm3.static.flickr.com/2342/2085768823_a0afd2773f.jpg\r\nhttp://www.junglewalk.com/animal-pictures/5/Dog-16009.jpg\r\nhttp://farm1.static.flickr.com/25/57104973_d32fbaf377.jpg\r\nhttp://farm1.static.flickr.com/31/57881227_33bb5aee3c.jpg\r\nhttp://farm2.static.flickr.com/1002/1463108181_fffb4c3d0d.jpg\r\nhttp://farm2.static.flickr.com/1079/1387120794_4700436bc7.jpg\r\nhttp://farm1.static.flickr.com/54/146461998_a2c11854c6.jpg\r\nhttp://farm2.static.flickr.com/1374/961389963_1bbc4bedef.jpg\r\nhttp://farm1.static.flickr.com/70/185844804_4cd5e62834.jpg\r\nhttp://farm1.static.flickr.com/203/478915730_9d1b9d76a5.jpg\r\nhttp://farm1.static.flickr.com/77/226146128_b2da0ede02.jpg\r\nhttp://static.flickr.com/1407/957787016_defee54bfb.jpg\r\nhttp://farm2.static.flickr.com/1252/1116742177_d190bbe33b.jpg\r\nhttp://static.flickr.com/2055/1859362869_b73c220a90.jpg\r\nhttp://farm2.static.flickr.com/1288/962234498_7168e11614.jpg\r\nhttp://bp1.blogger.com/_Aar_qNhncPc/RuAeJyPEfZI/AAAAAAAABhY/fKajihhKpHA/s400/Perro+Coste\xc3\xb1o.bmp\r\nhttp://farm3.static.flickr.com/2334/1492382652_b92ab8385c.jpg\r\nhttp://farm1.static.flickr.com/102/295241530_6001bd310b.jpg\r\nhttp://static.flickr.com/1259/1469874443_d9cd198fc7.jpg\r\nhttp://static.flickr.com/192/482969411_606de7f560.jpg\r\nhttp://farm1.static.flickr.com/34/69291956_f7be44e5cb.jpg\r\nhttp://farm1.static.flickr.com/14/18490844_5c1f793f24.jpg\r\nhttp://farm1.static.flickr.com/254/450406665_1068cb8f95.jpg\r\nhttp://farm2.static.flickr.com/1216/1414089898_5858de884c.jpg\r\nhttp://farm1.s ...
# 1524
# 1604

# %%
# !mkdir '/content/catdog_dev/' 
# !mkdir '/content/catdog_test/'

# %%
#Defining function to convert URL to images 
img_rows, img_cols = 32, 32 #number of rows and columns to convert the images to
input_shape = (img_rows, img_cols, 3)#format to store the images (rows, columns,channels) called channels last

def url_to_image(url):
	# download the image, convert it to a NumPy array, and then read
	# it into OpenCV format
	resp = urllib.request.urlopen(url)
	image = np.asarray(bytearray(resp.read()), dtype="uint8")
	image = cv2.imdecode(image, cv2.IMREAD_COLOR)
 
	# return the image
	return image

# %%
n_of_training_images=50   #The number of Development images to use
counter=0
for progress in range(10*n_of_training_images):#store all 200 INDIAN ELEPHANT images on a directory
    if (counter == n_of_training_images):
      break
    if (progress%10==0):
        print(progress)
    if not ie_split_urls[progress] == None:
      try:
        I = url_to_image(ie_split_urls[progress])
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/catdog_dev/ie.'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
          counter=counter+1
          print("Counter count :",counter)
      except:
        None
print("\n ALL THE DEV SET CATS- IMAGES STORED ON THE DIRECTORY\n")
print("Total Counter :" ,counter)

counter=0
for progress in range(10*n_of_training_images):#store all 200 AFRICAN ELEPHANT images on a directory
    if (counter == n_of_training_images):
      break 
    if (progress%10==0):
        print(progress)
    if not ae_split_urls[progress] == None:
      try:
        I = url_to_image(ae_split_urls[progress])
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/catdog_dev/ae.'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
          counter=counter+1
          print("Counter count :",counter)

      except:
        None
print("\n ALL THE DEV SET -DOGS IMAGES STORED ON THE DIRECTORY\n")
print("Total Counter :" ,counter)
# Out:
# 0
# Counter count : 1
# Counter count : 2
# Counter count : 3
# Counter count : 4
# Counter count : 5
# Counter count : 6
# 10
# Counter count : 7
# Counter count : 8
# Counter count : 9
# Counter count : 10
# Counter count : 11
# Counter count : 12
# Counter count : 13
# 20
# Counter count : 14
# Counter count : 15
# Counter count : 16
# Counter count : 17
# Counter count : 18
# Counter count : 19
# Counter count : 20
# Counter count : 21
# 30
# Counter count : 22
# Counter count : 23
# Counter count : 24
# Counter count : 25
# Counter count : 26
# 40
# Counter count : 27
# Counter count : 28
# Counter count : 29
# Counter count : 30
# Counter count : 31
# 50
# Counter count : 32
# Counter count : 33
# Counter count : 34
# Counter count : 35
# Counter count : 36
# Counter count : 37
# 60
# Counter count : 38
# Counter count : 39
# Counter count : 40
# Counter count : 41
# Counter count : 42
# Counter count : 43
# Counter count : 44
# 70
# Counter count : 45
# Counter count : 46
# Counter count : 47
# Counter count : 48
# Counter count : 49
# Counter count : 50
#
#  ALL THE DEV SET CATS- IMAGES STORED ON THE DIRECTORY
#
# Total Counter : 50
# 0
# Counter count : 1
# Counter count : 2
# Counter count : 3
# Counter count : 4
# Counter count : 5
# 10
# Counter count : 6
# Counter count : 7
# Counter count : 8
# Counter count : 9
# Counter count : 10
# Counter count : 11
# 20
# Counter count : 12
# Counter count : 13
# Counter count : 14
# Counter count : 15
# Counter count : 16
# Counter count : 17
# Counter count : 18
# Counter count : 19
# 30
# Counter count : 20
# Counter count : 21
# Counter count : 22
# Counter count : 23
# Counter count : 24
# Counter count : 25
# Counter count : 26
# 40
# Counter count : 27
# Counter count : 28
# Counter count : 29
# Counter count : 30
# Counter count : 31
# Counter count : 32
# 50
# Counter count : 33
# Counter count : 34
# Counter count : 35
# Counter count : 36
# Counter count : 37
# Counter count : 38
# Counter count : 39
# Counter count : 40
# 60
# Counter count : 41
# Counter count : 42
# Counter count : 43
# Counter count : 44
# Counter count : 45
# Counter count : 46
# 70
# Counter count : 47
# Counter count : 48
# Counter count : 49
# Counter count : 50
#
#  ALL THE DEV SET -DOGS IMAGES STORED ON THE DIRECTORY
#
# Total Counter : 50

# %%
#Storing Test Data data:
n_of_testing_images=50
counter=0
for progress in range(10*n_of_testing_images):#store all the 50INDIAN ELEPHANT TEST IMAGES on a directory
    if (counter >=n_of_testing_images):
      break
    if (progress%10==0):
        print(progress)
    if not ie_split_urls[progress] == None:
      try:
        I = url_to_image(ie_split_urls[n_of_training_images+progress])#get images that are different from the ones used for training
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/catdog_test/ie.'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
          counter=counter+1
          print("Counter count: ",counter)
      except:
        None
print("\n ALL THE CAT TEST IMAGES STORED ON THE DIRECTORY\n")
print("Total Count: ",counter)

counter=0
for progress in range(10*n_of_testing_images):#store all 50 AFRICAN ELEPEHANT TEST IMAGES on a driectory
    if (counter >=n_of_testing_images):
      break
    if (progress%10==0):
        print(progress)
    if not ae_split_urls[progress] == None:
      try:
        I = url_to_image(ae_split_urls[n_of_training_images+progress])#get images that are different from the ones used for training
        if (len(I.shape))==3: #check if the image has width, length and channels
          save_path = '/content/catdog_test/ae.'+str(progress)+'.jpg'#create a name of each image
          cv2.imwrite(save_path,I)
          counter=counter+1
          print("Counter count: ",counter)
      except:
        None
print("\n ALL THE DOGS TEST IMAGES STORED ON THE DIRECTORY\n")
print("Total Count: ",counter)
# Out:
# 0
# Counter count:  1
# Counter count:  2
# Counter count:  3
# Counter count:  4
# Counter count:  5
# Counter count:  6
# 10
# Counter count:  7
# Counter count:  8
# Counter count:  9
# Counter count:  10
# Counter count:  11
# Counter count:  12
# Counter count:  13
# 20
# Counter count:  14
# Counter count:  15
# Counter count:  16
# Counter count:  17
# Counter count:  18
# Counter count:  19
# Counter count:  20
# 30
# Counter count:  21
# Counter count:  22
# Counter count:  23
# Counter count:  24
# Counter count:  25
# Counter count:  26
# Counter count:  27
# 40
# Counter count:  28
# Counter count:  29
# Counter count:  30
# Counter count:  31
# Counter count:  32
# Counter count:  33
# Counter count:  34
# Counter count:  35
# Counter count:  36
# 50
# Counter count:  37
# Counter count:  38
# Counter count:  39
# Counter count:  40
# Counter count:  41
# Counter count:  42
# Counter count:  43
# 60
# Counter count:  44
# Counter count:  45
# Counter count:  46
# Counter count:  47
# Counter count:  48
# Counter count:  49
# Counter count:  50
#
#  ALL THE CAT TEST IMAGES STORED ON THE DIRECTORY
#
# Total Count:  50
# 0
# Counter count:  1
# Counter count:  2
# Counter count:  3
# Counter count:  4
# Counter count:  5
# Counter count:  6
# Counter count:  7
# Counter count:  8
# 10
# Counter count:  9
# Counter count:  10
# Counter count:  11
# Counter count:  12
# Counter count:  13
# Counter count:  14
# 20
# Counter count:  15
# Counter count:  16
# Counter count:  17
# Counter count:  18
# Counter count:  19
# Counter count:  20
# 30
# Counter count:  21
# Counter count:  22
# Counter count:  23
# Counter count:  24
# 40
# Counter count:  25
# Counter count:  26
# Counter count:  27
# Counter count:  28
# Counter count:  29
# 50
# Counter count:  30
# Counter count:  31
# Counter count:  32
# Counter count:  33
# Counter count:  34
# Counter count:  35
# 60
# Counter count:  36
# Counter count:  37
# Counter count:  38
# Counter count:  39
# Counter count:  40
# Counter count:  41
# 70
# Counter count:  42
# Counter count:  43
# Counter count:  44
# Counter count:  45
# Counter count:  46
# 80
# Counter count:  47
# Counter count:  48
# Counter count:  49
# Counter count:  50
#
#  ALL THE DOGS TEST IMAGES STORED ON THE DIRECTORY
#
# Total Count:  50

# %%
# Path to the train folder
import os
original_train = '/content/catdog_dev/'
 
filenames = os.listdir(original_train)
categories = []
for filename in filenames:
  category = filename.split('.')[0]
  if category == 'ie':
    categories.append('0')
  else:
    categories.append('1')


#Create dataframe for Development

import pandas as pd
data = pd.DataFrame({'filename':filenames,'label':categories})
data.to_csv("original_catdog_dev.csv",index=False)

# %%
data
# Out:
#      filename label
# 0   ie.70.jpg     0
# 1   ie.55.jpg     0
# 2   ie.36.jpg     0
# 3   ae.21.jpg     1
# 4   ie.47.jpg     0
# ..        ...   ...
# 95   ie.2.jpg     0
# 96  ie.43.jpg     0
# 97  ie.28.jpg     0
# 98  ae.62.jpg     1
# 99  ie.21.jpg     0
#
# [100 rows x 2 columns]

# %%
# Path to the test folder
import os
original_test = '/content/catdog_test/'
 
filenames = os.listdir(original_test)
categories = []
for filename in filenames:
  category = filename.split('.')[0]
  if category == 'ie':
    categories.append(0)
  else:
    categories.append(1)

data_test = pd.DataFrame({'filename':filenames,'label':categories})
data_test.to_csv("original_catdog_test.csv",index=False)

# %%
# THE MODELING PART

model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (7,7),padding = 'valid',activation ='relu', input_shape=x_train.shape[1:]))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.20))


model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'valid',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.15))


model.add(Conv2D(filters = 512, kernel_size = (3,3),padding = 'valid',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.05))

model.add(Flatten())
model.add(Dense(1024))
model.add(Activation('relu'))
model.add(Dense(1, activation = "sigmoid"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        4736
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 9, 9, 64)          51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 2, 2, 512)         295424
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              525312
# _________________________________________________________________
# activation (Activation)      (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 877,761
# Trainable params: 877,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
# EarlyStopping, Callbacks and Model Compilation
from keras.callbacks import ReduceLROnPlateau
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping
filepath = "weights-improvement-experiment3.h5"
checkpoint = ModelCheckpoint(filepath, monitor = 'val_accuracy', verbose=1, save_best_only=True, mode='max')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20, min_delta=0.01, baseline=2.0)
red_lr= ReduceLROnPlateau(monitor='val_accuracy',patience=3,verbose=1,factor=0.1)
callbacks_list = [checkpoint, es,red_lr]
model.compile(loss='binary_crossentropy',optimizer=Adam(lr=0.001),metrics=['accuracy'])

# %%
datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=5,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)

datagen.fit(x_train)

dev_generator = datagen.flow_from_dataframe(dataframe=data, directory=original_train,
                                             x_col='filename',
                                             y_col='label',
                                             target_size=(32,32),
                                             class_mode='binary',
                                             #batch_size=10,
                                             #subset='validation',
                                             #shuffle=True,
                                             #seed=7,
                                            color_mode='rgb')

test_datagen=ImageDataGenerator(rescale=1./255)

test_generator=test_datagen.flow_from_dataframe(dataframe=data_test,
                                                directory="/content/catdog_test/",
                                                x_col="filename",
                                                y_col=None,
                                                #batch_size=10,
                                                #seed=7,
                                                #shuffle=False,
                                                class_mode=None,
                                                target_size=(32,32),
                                                color_mode='rgb')
# Out:
# Found 100 validated image filenames belonging to 2 classes.
# Found 100 validated image filenames.

# %%
# Fitting the Model
history=model.fit(datagen.flow(x_train, y_train),epochs=50,verbose=1,callbacks=callbacks_list,validation_data=dev_generator)
# Out:
# Epoch 1/50
# 313/313 [==============================] - 13s 19ms/step - loss: 0.7053 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
#
# Epoch 00001: val_accuracy improved from -inf to 0.50000, saving model to weights-improvement-experiment3.h5
# Epoch 2/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6875 - val_accuracy: 0.5000
#
# Epoch 00002: val_accuracy did not improve from 0.50000
# Epoch 3/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6930 - val_accuracy: 0.5000
#
# Epoch 00003: val_accuracy did not improve from 0.50000
# Epoch 4/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6929 - val_accuracy: 0.5100
#
# Epoch 00004: val_accuracy improved from 0.50000 to 0.51000, saving model to weights-improvement-experiment3.h5
# Epoch 5/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6979 - val_accuracy: 0.5000
#
# Epoch 00005: val_accuracy did not improve from 0.51000
# Epoch 6/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
#
# Epoch 00006: val_accuracy did not improve from 0.51000
# Epoch 7/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
#
# Epoch 00007: val_accuracy did not improve from 0.51000
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 8/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
#
# Epoch 00008: val_accuracy did not improve from 0.51000
# Epoch 9/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6928 - val_accuracy: 0.5100
#
# Epoch 00009: val_accuracy did not improve from 0.51000
# Epoch 10/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
#
# Epoch 00010: val_accuracy did not improve from 0.51000
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 11/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6970 - val_accuracy: 0.4900
#
# Epoch 00011: val_accuracy did not improve from 0.51000
# Epoch 12/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6925 - val_accuracy: 0.5100
#
# Epoch 00012: val_accuracy did not improve from 0.51000
# Epoch 13/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
#
# Epoch 00013: val_accuracy did not improve from 0.51000
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 14/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6911 - val_accuracy: 0.5100
#
# Epoch 00014: val_accuracy did not improve from 0.51000
# Epoch 15/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
#
# Epoch 00015: val_accuracy did not improve from 0.51000
# Epoch 16/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6928 - val_accuracy: 0.5000
#
# Epoch 00016: val_accuracy did not improve from 0.51000
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 17/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
#
# Epoch 00017: val_accuracy did not improve from 0.51000
# Epoch 18/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6950 - val_accuracy: 0.5000
#
# Epoch 00018: val_accuracy did not improve from 0.51000
# Epoch 19/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6922 - val_accuracy: 0.5100
#
# Epoch 00019: val_accuracy did not improve from 0.51000
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Epoch 20/50
# 313/313 [==============================] - 6s 18ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6939 - val_accuracy: 0.4900
#
# Epoch 00020: val_accuracy did not improve from 0.51000
# Epoch 21/50
# 313/313 [==============================] - 6s 19ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6876 - val_accuracy: 0.5200
#
# Epoch 00021: val_accuracy improved from 0.51000 to 0.52000, saving model to weights-improvement-experiment3.h5
# Epoch 00021: early stopping

# %% [markdown]
# ### Plotting Accuracy of Train VS Validation

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epochs/iterations")
plt.legend(['Train','Validation'], loc="upper left")
plt.show()

# %% [markdown]
# ### Plotting Loss of Train VS Validation

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Model LOSS")
plt.ylabel("Loss")
plt.xlabel("Epochs/iterations")
plt.legend(['Train','Validation'], loc="upper left")
plt.show()

# %% [markdown]
# ### Predicting the Output

# %%
test_generator.reset()
predictions=np.argmax(model.predict_generator(test_generator),axis=-1)

filenames=test_generator.filenames
results=pd.DataFrame({"Filename":filenames,"Predictions":predictions})

results.to_csv("results_catsdogs_test.csv",index=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1905: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
preds=results['Predictions']

# %%
preds=pd.get_dummies(preds)

# %%
preds
# Out:
#     0
# 0   1
# 1   1
# 2   1
# 3   1
# 4   1
# .. ..
# 95  1
# 96  1
# 97  1
# 98  1
# 99  1
#
# [100 rows x 1 columns]

# %%
preds.to_csv('preds.csv')

# %%
data_test['label']
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    0
# 99    1
# Name: label, Length: 100, dtype: int64

# %%
from google.colab import files
files.download('preds.csv')

# %% [markdown]
# #Error Analysis and Data Mismatch

# %% [markdown]
# ![dl_exp_3_1.png](data:image/png;base64,...)

# %% [markdown]
# ![dl_exp_3_2.png](data:image/png;base64,...)

# %% [markdown]
# ![dl_exp_3_3.png](data:image/png;base64,...)

# %% [markdown]
# ### Confusion Matrix

# %%
plt.figure(figsize=(10,5))
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
cm = confusion_matrix(np.asarray(data_test['label']), results['Predictions'])
ax = plt.subplot()

import seaborn as sns
sns.heatmap(cm, annot = True, ax = ax)

ax.set_xlabel('Predicted')
ax.set_ylabel('Original')
ax.set_title('Confusion_matrix')
# Out:
# Text(0.5, 1.0, 'Confusion_matrix')

# %%
print(classification_report(np.asarray(data_test['label']), results["Predictions"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67        50
#            1       0.00      0.00      0.00        50
#
#     accuracy                           0.50       100
#    macro avg       0.25      0.50      0.33       100
# weighted avg       0.25      0.50      0.33       100
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
score = accuracy_score(results['Predictions'],data_test["label"])
print('Test Accuracy:',score*100)
# Out:
# Test Accuracy: 50.0
